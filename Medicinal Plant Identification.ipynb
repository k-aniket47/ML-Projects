# %%
import numpy as np
import pandas as pd 
import keras
import cv2 as cv
import tensorflow 
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
import cv2    
from sklearn.metrics import confusion_matrix
import os

# %%
train_path = r"D:\Dataset\Medicinal Leaf Images\train"
test_path = r"D:\Dataset\Medicinal Leaf Images\test"

print("type of Images in Train dataset"+str(os.listdir(train_path)))
print("type of Images in Test dataset"+str(os.listdir(test_path)))
# Out:
# type of Images in Train dataset['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']
# type of Images in Test dataset['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']

# %%
rows, cols = (1, 5)
import matplotlib.pyplot as plt
for categories in os.listdir(train_path):
    print(f'{categories} images:')
    path = f'{train_path}/{categories}'    
    fig = plt.figure(figsize = (13, 8))
    for i in range(rows * cols):
        fig.add_subplot(rows, cols, i+1)
        image_id = os.listdir(path)[np.random.randint(0, 30)]
        image = cv.imread(path + f'/{image_id}')
        plt.imshow(image[:, :, ::-1])
        plt.title(image_id)
        plt.axis('off')
    plt.show()
# Out:
# Alpinia Galanga (Rasna) images:
# Amaranthus Viridis (Arive-Dantu) images:
# Artocarpus Heterophyllus (Jackfruit) images:
# Azadirachta Indica (Neem) images:
# Basella Alba (Basale) images:
# Brassica Juncea (Indian Mustard) images:
# Carissa Carandas (Karanda) images:
# Citrus Limon (Lemon) images:
# Ficus Auriculata (Roxburgh fig) images:
# Ficus Religiosa (Peepal Tree) images:
# Hibiscus Rosa-sinensis images:
# Jasminum (Jasmine) images:
# Mangifera Indica (Mango) images:
# Mentha (Mint) images:
# Moringa Oleifera (Drumstick) images:
# Muntingia Calabura (Jamaica Cherry-Gasagase) images:
# Murraya Koenigii (Curry) images:
# Nerium Oleander (Oleander) images:
# Nyctanthes Arbor-tristis (Parijata) images:
# Ocimum Tenuiflorum (Tulsi) images:
# Piper Betle (Betel) images:
# Plectranthus Amboinicus (Mexican Mint) images:
# Pongamia Pinnata (Indian Beech) images:
# Psidium Guajava (Guava) images:
# Punica Granatum (Pomegranate) images:
# Santalum Album (Sandalwood) images:
# Syzygium Cumini (Jamun) images:
# Syzygium Jambos (Rose Apple) images:
# Tabernaemontana Divaricata (Crape Jasmine) images:
# Trigonella Foenum-graecum (Fenugreek) images:

# %%
from tqdm import tqdm
class_names = ['Alpinia Galanga (Rasna)', 'Amaranthus Viridis (Arive-Dantu)', 'Artocarpus Heterophyllus (Jackfruit)', 'Azadirachta Indica (Neem)', 'Basella Alba (Basale)', 'Brassica Juncea (Indian Mustard)', 'Carissa Carandas (Karanda)', 'Citrus Limon (Lemon)', 'Ficus Auriculata (Roxburgh fig)', 'Ficus Religiosa (Peepal Tree)', 'Hibiscus Rosa-sinensis', 'Jasminum (Jasmine)', 'Mangifera Indica (Mango)', 'Mentha (Mint)', 'Moringa Oleifera (Drumstick)', 'Muntingia Calabura (Jamaica Cherry-Gasagase)', 'Murraya Koenigii (Curry)', 'Nerium Oleander (Oleander)', 'Nyctanthes Arbor-tristis (Parijata)', 'Ocimum Tenuiflorum (Tulsi)', 'Piper Betle (Betel)', 'Plectranthus Amboinicus (Mexican Mint)', 'Pongamia Pinnata (Indian Beech)', 'Psidium Guajava (Guava)', 'Punica Granatum (Pomegranate)', 'Santalum Album (Sandalwood)', 'Syzygium Cumini (Jamun)', 'Syzygium Jambos (Rose Apple)', 'Tabernaemontana Divaricata (Crape Jasmine)', 'Trigonella Foenum-graecum (Fenugreek)']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
    
    datasets = [r"D:\Dataset\Medicinal Leaf Images\train",r"D:\Dataset\Medicinal Leaf Images\test"]
    output = []
    
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
       
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
               
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
               
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
              
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(x_train, y_train), (x_test, y_test) = load_data()
# Out:
# Loading D:\Dataset\Medicinal Leaf Images\train
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 53.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 51.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 49.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 52.94it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 43.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 48.57it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 48.44it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 48.03it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 46.97it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 48.29it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 55.08it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 46.95it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 52.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 50.62it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 52.45it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 51.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 48.16it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 54.99it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 51.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 53.07it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 49.42it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 52.82it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 45.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 44.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 49.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 49.28it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 48.73it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 53.38it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 44.44it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 127/127 [00:02<00:00, 55.68it/s]
# Loading D:\Dataset\Medicinal Leaf Images\test
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 47.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 48.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 38.33it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 50.00it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 49.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 53.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 51.23it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 51.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 50.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 52.63it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 52.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 48.24it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 39.37it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 41.67it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 50.11it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 43.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 49.78it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 43.48it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 49.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 49.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 43.73it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 43.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 38.98it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 40.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 42.59it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 44.75it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 45.45it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 53.96it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 49.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 49.57it/s]

# %%
batch_size = 128  
epochs = 30
data_augmentation = True
num_classes = 30

subtract_pixel_mean = True
n = 3
version = 1

if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2
model_type = 'ResNet%dv%d' % (depth, version)

# %%
print(model_type)
# Out:
# ResNet20v1

# %%
input_shape = x_train.shape[1:]
print(input_shape)
# Out:
# (150, 150, 3)

# %%
# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (3810, 150, 150, 3)
# 3810 train samples
# 690 test samples
# y_train shape: (3810,)

# %%
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=30):
    
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


def resnet_v2(input_shape, depth, num_classes=30):
    
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'IntelImageClass_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 150, 150, 16  448         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 150, 150, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 150, 150, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 150, 150, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 150, 150, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 150, 150, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 150, 150, 16  2320        ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 150, 150, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 150, 150, 16  0           ['activation[0][0]',
#                                 )                                 'batch_normalization_2[0][0]']
#
#  activation_2 (Activation)      (None, 150, 150, 16  0           ['add[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 150, 150, 16  2320        ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 150, 150, 16  64         ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 150, 150, 16  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 150, 150, 16  2320        ['activation_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 150, 150, 16  64         ['conv2d_4[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 150, 150, 16  0           ['activation_2[0][0]',
#                                 )                                 'batch_normalization_4[0][0]']
#
#  activation_4 (Activation)      (None, 150, 150, 16  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 150, 150, 16  2320        ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 150, 150, 16  64         ['conv2d_5[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 150, 150, 16  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 150, 150, 16  2320        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 150, 150, 16  64         ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  add_2 (Add)                    (None, 150, 150, 16  0           ['activation_4[0][0]',
#                                 )                                 'batch_normalization_6[0][0]']
#
#  activation_6 (Activation)      (None, 150, 150, 16  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 75, 75, 32)   4640        ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 75, 75, 32)  128         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 75, 75, 32)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 75, 75, 32)   9248        ['activation_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 75, 75, 32)   544         ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 75, 75, 32)  128         ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 75, 75, 32)   0           ['conv2d_9[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 75, 75, 32)   0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 75, 75, 32)   9248        ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 75, 75, 32)  128         ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 75, 75, 32)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 75, 75, 32)   9248        ['activation_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 75, 75, 32)  128         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 75, 75, 32)   0           ['activation_8[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  activation_10 (Activation)     (None, 75, 75, 32)   0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 75, 75, 32)   9248        ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 75, 75, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 75, 75, 32)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 75, 75, 32)   9248        ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 75, 75, 32)  128         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 75, 75, 32)   0           ['activation_10[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  activation_12 (Activation)     (None, 75, 75, 32)   0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 38, 38, 64)   18496       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 38, 38, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 38, 38, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 38, 38, 64)   36928       ['activation_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 38, 38, 64)   2112        ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 38, 38, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 38, 38, 64)   0           ['conv2d_16[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_14 (Activation)     (None, 38, 38, 64)   0           ['add_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 38, 38, 64)   36928       ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 38, 38, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 38, 38, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 38, 38, 64)   36928       ['activation_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 38, 38, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 38, 38, 64)   0           ['activation_14[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 38, 38, 64)   0           ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 38, 38, 64)   36928       ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 38, 38, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 38, 38, 64)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 38, 38, 64)   36928       ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 38, 38, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 38, 38, 64)   0           ['activation_16[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_18 (Activation)     (None, 38, 38, 64)   0           ['add_8[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 64)    0           ['activation_18[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 1024)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 30)           30750       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 304,542
# Trainable params: 303,166
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
datagen.fit(x_train)

# %%
model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Learning rate:  0.001
# Epoch 1/30
# 30/30 [==============================] - ETA: 0s - loss: 3.0788 - accuracy: 0.2129 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 405s 13s/step - loss: 3.0788 - accuracy: 0.2129 - val_loss: 7.1338 - val_accuracy: 0.0580 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/30
# 30/30 [==============================] - ETA: 0s - loss: 1.9137 - accuracy: 0.4869 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 368s 12s/step - loss: 1.9137 - accuracy: 0.4869 - val_loss: 6.1442 - val_accuracy: 0.0797 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/30
# 30/30 [==============================] - ETA: 0s - loss: 1.4907 - accuracy: 0.6055 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 362s 12s/step - loss: 1.4907 - accuracy: 0.6055 - val_loss: 5.9630 - val_accuracy: 0.0768 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/30
# 30/30 [==============================] - ETA: 0s - loss: 1.2690 - accuracy: 0.6572 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 345s 11s/step - loss: 1.2690 - accuracy: 0.6572 - val_loss: 5.6334 - val_accuracy: 0.0899 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/30
# 30/30 [==============================] - ETA: 0s - loss: 1.1163 - accuracy: 0.7173 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 351s 12s/step - loss: 1.1163 - accuracy: 0.7173 - val_loss: 4.3420 - val_accuracy: 0.1754 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/30
# 30/30 [==============================] - ETA: 0s - loss: 1.0287 - accuracy: 0.7325 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 350s 12s/step - loss: 1.0287 - accuracy: 0.7325 - val_loss: 4.8472 - val_accuracy: 0.1580 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/30
# 30/30 [==============================] - ETA: 0s - loss: 0.8983 - accuracy: 0.7745 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 337s 11s/step - loss: 0.8983 - accuracy: 0.7745 - val_loss: 3.3353 - val_accuracy: 0.3072 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/30
# 30/30 [==============================] - ETA: 0s - loss: 0.8268 - accuracy: 0.7940 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 331s 11s/step - loss: 0.8268 - accuracy: 0.7940 - val_loss: 3.6916 - val_accuracy: 0.2812 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/30
# 30/30 [==============================] - ETA: 0s - loss: 0.7799 - accuracy: 0.8097 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 331s 11s/step - loss: 0.7799 - accuracy: 0.8097 - val_loss: 3.4944 - val_accuracy: 0.2826 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/30
# 30/30 [==============================] - ETA: 0s - loss: 0.6919 - accuracy: 0.8273 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 331s 11s/step - loss: 0.6919 - accuracy: 0.8273 - val_loss: 2.6353 - val_accuracy: 0.4667 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/30
# 30/30 [==============================] - ETA: 0s - loss: 0.6527 - accuracy: 0.8483 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 331s 11s/step - loss: 0.6527 - accuracy: 0.8483 - val_loss: 1.6979 - val_accuracy: 0.6174 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/30
# 30/30 [==============================] - ETA: 0s - loss: 0.6416 - accuracy: 0.8480 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 330s 11s/step - loss: 0.6416 - accuracy: 0.8480 - val_loss: 1.5764 - val_accuracy: 0.6565 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/30
# 30/30 [==============================] - ETA: 0s - loss: 0.5850 - accuracy: 0.8682 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 516s 17s/step - loss: 0.5850 - accuracy: 0.8682 - val_loss: 2.1284 - val_accuracy: 0.5101 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/30
# 30/30 [==============================] - ETA: 0s - loss: 0.5889 - accuracy: 0.8648 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 336s 11s/step - loss: 0.5889 - accuracy: 0.8648 - val_loss: 1.0163 - val_accuracy: 0.7652 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/30
# 30/30 [==============================] - ETA: 0s - loss: 0.5403 - accuracy: 0.8764 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 336s 11s/step - loss: 0.5403 - accuracy: 0.8764 - val_loss: 1.9414 - val_accuracy: 0.6319 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/30
# 30/30 [==============================] - ETA: 0s - loss: 0.4933 - accuracy: 0.8885 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 335s 11s/step - loss: 0.4933 - accuracy: 0.8885 - val_loss: 0.9536 - val_accuracy: 0.7957 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/30
# 30/30 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.8911 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 333s 11s/step - loss: 0.4907 - accuracy: 0.8911 - val_loss: 1.0591 - val_accuracy: 0.7681 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/30
# 30/30 [==============================] - ETA: 0s - loss: 0.4357 - accuracy: 0.9108 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 334s 11s/step - loss: 0.4357 - accuracy: 0.9108 - val_loss: 1.0928 - val_accuracy: 0.7609 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/30
# 30/30 [==============================] - ETA: 0s - loss: 0.4304 - accuracy: 0.9105 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 334s 11s/step - loss: 0.4304 - accuracy: 0.9105 - val_loss: 0.9455 - val_accuracy: 0.8058 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/30
# 30/30 [==============================] - ETA: 0s - loss: 0.4303 - accuracy: 0.9126 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 333s 11s/step - loss: 0.4303 - accuracy: 0.9126 - val_loss: 1.0840 - val_accuracy: 0.7826 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.9257 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 333s 11s/step - loss: 0.3895 - accuracy: 0.9257 - val_loss: 3.3135 - val_accuracy: 0.5217 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/30
# 30/30 [==============================] - ETA: 0s - loss: 0.4008 - accuracy: 0.9249 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 350s 12s/step - loss: 0.4008 - accuracy: 0.9249 - val_loss: 0.8331 - val_accuracy: 0.8072 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3945 - accuracy: 0.9236 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 346s 11s/step - loss: 0.3945 - accuracy: 0.9236 - val_loss: 0.7334 - val_accuracy: 0.8565 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3622 - accuracy: 0.9318 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 336s 11s/step - loss: 0.3622 - accuracy: 0.9318 - val_loss: 0.7292 - val_accuracy: 0.8261 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.9265 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 385s 13s/step - loss: 0.3894 - accuracy: 0.9265 - val_loss: 0.6015 - val_accuracy: 0.8884 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3393 - accuracy: 0.9420 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 368s 12s/step - loss: 0.3393 - accuracy: 0.9420 - val_loss: 0.6251 - val_accuracy: 0.8870 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.9465 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 359s 12s/step - loss: 0.3163 - accuracy: 0.9465 - val_loss: 0.4758 - val_accuracy: 0.9130 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3225 - accuracy: 0.9475 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 363s 12s/step - loss: 0.3225 - accuracy: 0.9475 - val_loss: 0.6651 - val_accuracy: 0.8754 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.9459 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 365s 12s/step - loss: 0.3230 - accuracy: 0.9459 - val_loss: 0.7362 - val_accuracy: 0.8565 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/30
# 30/30 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.9415 WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 30/30 [==============================] - 351s 12s/step - loss: 0.3339 - accuracy: 0.9415 - val_loss: 0.5882 - val_accuracy: 0.8797 - lr: 0.0010

# %%
def display_random_image(class_names, images, labels):
   
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Predicte Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 22/22 [==============================] - 13s 584ms/step - loss: 0.5882 - accuracy: 0.8797
# Test loss: 0.5881519317626953
# Test accuracy: 0.8797101378440857

# %%
predictions = model.predict(x_test)     
pred_labels = np.argmax(predictions, axis = 1)
display_random_image(class_names, x_test, pred_labels)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
